# %%
'''Step 1: Create a Project Directory
Open a terminal or command prompt and run:

bash
Copy
Edit
mkdir my_project
cd my_project
Step 2: Create a Virtual Environment
Run the following command:

bash
Copy
Edit
python -m venv venv
This will create a virtual environment named venv inside your project directory.

Step 3: Activate the Virtual Environment
For Windows:

bash
Copy
Edit
venv\Scripts\activate
For macOS/Linux:

bash
Copy
Edit
source venv/bin/activate
Step 4: Verify Virtual Environment is Active
Run the following command:

bash
Copy
Edit
which python  # macOS/Linux
where python  # Windows
The output should show a path inside the venv folder.

Step 5: Install Required Packages (Optional)
If you need any libraries, install them inside the virtual environment:

bash
Copy
Edit
pip install requests beautifulsoup4 pandas lxml
Step 6: Deactivate the Virtual Environment
Once you're done, deactivate the virtual environment:

bash
Copy
Edit
deactivate
 Now, you have a project directory with an isolated virtual environment '''
