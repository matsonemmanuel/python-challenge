# %%
import random
import string

def random_user_id():
    return ''.join(random.choices(string.ascii_lowercase + string.digits, k=6))

# Example usage:
print(random_user_id())
# Out:
# 2a0lts

# %%
import random
import string

def user_id_gen_by_user():
    # Get user inputs
    while True:
        try:
            num_chars = int(input("Enter the number of characters for each ID: "))
            break
        except ValueError:
            print("Please enter a valid integer for the number of characters.")
    
    while True:
        try:
            num_ids = int(input("Enter the number of IDs to generate: "))
            break
        except ValueError:
            print("Please enter a valid integer for the number of IDs.")
    
    # Function to generate a single random user ID
    def generate_user_id():
        return ''.join(random.choices(string.ascii_lowercase + string.digits, k=num_chars))
    
    # Generate and return the list of IDs
    user_ids = [generate_user_id() for _ in range(num_ids)]
    return user_ids

# Example usage:
print(user_id_gen_by_user())
# Out:
# ['a2tdin5', 'b433sry', 'gwixj6n']

# %%
import random

def rgb_color_gen():
    return (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))

# Example usage:
print(rgb_color_gen())
# Out:
# (103, 194, 111)

# %%
import random

def list_of_hexa_colors(num_colors):
    hex_chars = '0123456789abcdef'
    colors = []
    
    for _ in range(num_colors):
        color = '#' + ''.join(random.choices(hex_chars, k=6))
        colors.append(color)
    
    return colors

# Example usage:
print(list_of_hexa_colors(5))
# Out:
# ['#da8e55', '#2a727c', '#36e8fa', '#8eaa9b', '#4ef4f8']

# %%
import random

def list_of_rgb_colors(num_colors):
    colors = []
    
    for _ in range(num_colors):
        color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
        colors.append(color)
    
    return colors

# Example usage:
print(list_of_rgb_colors(5))
# Out:
# [(46, 122, 0), (85, 235, 54), (245, 126, 42), (170, 47, 105), (200, 2, 189)]

# %%
import random

def generate_colors(num_colors, color_type):
    def generate_hexa_color():
        hex_chars = '0123456789abcdef'
        return '#' + ''.join(random.choices(hex_chars, k=6))
    
    def generate_rgb_color():
        return (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    
    colors = []
    
    for _ in range(num_colors):
        if color_type == "hex":
            colors.append(generate_hexa_color())
        elif color_type == "rgb":
            colors.append(generate_rgb_color())
        else:
            raise ValueError("Invalid color type. Choose either 'hex' or 'rgb'.")
    
    return colors

# Example usage:
print(generate_colors(5, "hex"))  # Generate 5 hex colors
print(generate_colors(3, "rgb"))
# Out:
# ['#978da8', '#b54ef6', '#c9caa3', '#2979e7', '#4ec6b3']
# [(162, 253, 139), (58, 197, 110), (250, 209, 228)]

# %%
import random

def shuffle_list(lst):
    random.shuffle(lst)
    return lst

# Example usage:
my_list = [1, 2, 3, 4, 5]
print(shuffle_list(my_list))
# Out:
# [5, 3, 1, 2, 4]

# %%
import random

def unique_random_numbers():
    return random.sample(range(10), 7)

# Example usage:
print(unique_random_numbers())
# Out:
# [7, 8, 0, 9, 4, 2, 1]
